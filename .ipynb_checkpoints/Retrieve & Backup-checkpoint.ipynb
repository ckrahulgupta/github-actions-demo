# %%
import os
import subprocess

# %%
result = subprocess.run(
			['sfdx', 'project', 'retrieve', 'start', '--target-org', '--manifest', 'manifest/package.xml', '--api-version', '60.0'], 
			capture_output=True, 
			text=True
		)

# %%
result.stdout
# Out:
# '\n \x1b──────────────\x1b Retrieving Metadata \x1b──────────────\x1b\n\n\n \x1b◼\x1b Preparing retrieve request\n \x1b◼\x1b Sending request to org\n \x1b◼\x1b Waiting for the org to respond\n \x1b◼\x1b Done\n\n Status: \x1b⠁\x1b\n Elapsed Time: 0ms\n\n\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[G\n \x1b──────────────\x1b Retrieving Metadata \x1b──────────────\x1b\n\n Retrieving v63.0 metadata from rahul.gupta@cloudkaptan.com.cfa.dev using the\n v60.0 SOAP API\n\n \x1b✔\x1b Preparing retrieve request \x1b14ms\x1b\n \x1b⣾\x1b Sending request to org \x1b19ms\x1b\n \x1b◼\x1b Waiting for the org to respond\n \x1b◼\x1b Done\n\n Status: \x1b⠁\x1b\n Elapsed Time: 34ms\n\n\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K\x1b[1A\x1b[2K
# ...

# %%
result.stderr
# Out:
# ' \x1b›\x1b   Warning: @salesforce/cli update available from \x1b2.76.7\x1b to \x1b2.82.6\x1b.\n'

# %%
result.returncode
# Out:
# 0

# %%
os.system('sfdx project retrieve start --manifest manifest/package.xml --api-version 60.0')
# Out:
#  ›   Warning: @salesforce/cli update available from 2.76.7 to 2.82.6.
#  ────────────── Retrieving Metadata ──────────────
#
#
#  ◼ Preparing retrieve request
#  ◼ Sending request to org
#  ◼ Waiting for the org to respond
#  ◼ Done
#
#  Status: ⠁
#  Elapsed Time: 0ms
#
#
#  ────────────── Retrieving Metadata ──────────────
#
#  Retrieving v63.0 metadata from rahul.gupta@cloudkaptan.com.cfa.dev using the
#  v60.0 SOAP API
#
#  ✔ Preparing retrieve request 9ms
#  ⣾ Sending request to org 22ms
#  ◼ Waiting for the org to respond
#  ◼ Done
#
#  Status: ⠁
#  Elapsed Time: 34ms
#
#
#  ────────────── Retrieving Metadata ──────────────
#
#  Retrieving v63.0 metadata from rahul.gupta@cloudkaptan.com.cfa.dev using the
#  v60.0 SOAP API
#
#  ✔ Preparing retrieve request 9ms
#  ⣾ Sending request to org 52ms
#  ◼ Waiting for the org to respond
#  ◼ Done
#
#  Status: ⠁
#  Elapsed Time: 60ms
#
#
#  ────────────── Retrieving Metadata ──────────────
#
# ...
